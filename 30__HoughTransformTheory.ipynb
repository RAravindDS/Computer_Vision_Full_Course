# %% [markdown]
# ### Hough Transform is popular technique to detect the shape, if the shape was given in a mathematical form,
# - It can detect the shape even if it is broken or distorted a little bit.
#
# **The line in the image is represented by with two varaibles.**
# 1. cartesian equation y = mx + c ( It can represent in the mc space)
# 2. polar equation rho = xcos(theta) + ysin(theta)
#
# ![image.png](attachment:0ac8982a-e3ce-4b69-9174-e39de4b71f87.png)

# %% [markdown]
# * It is easy to manage the point instead of line, this is what the mc space doing.
#
# **The Opposite of this is also possible**
# ![image.png](attachment:b9b5c5be-c996-44ae-8417-f0e479b94b19.png)

# %% [markdown]
# **This hough Transform helps to convert the points to point**
# ![image.png](attachment:663835c4-fa62-4719-b360-e05a449fc631.png)

# %% [markdown]
# **We do the same thing in the Polar Co-ordinate the system**
# ![image.png](attachment:ecbfb605-9159-4d7b-bda0-bbef80df8db9.png)

# %% [markdown]
# **thetta - angle of the line, r - distance**
# ![image.png](attachment:4283c623-c8ff-4eae-a1d5-5ccdb87f2804.png)

# %% [markdown]
# ![image.png](attachment:5edad242-53e6-4ff5-8b20-813d4ed4f722.png)

# %% [markdown]
# ![image.png](attachment:9a56fb9b-e0e9-4057-b346-c2162456e206.png)

# %% [markdown]
# ![image.png](attachment:d3bac228-8fb3-42c2-b056-f4d48e92e4c8.png)
